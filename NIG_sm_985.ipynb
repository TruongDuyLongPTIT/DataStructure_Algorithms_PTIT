# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongDuyLongPTIT/DataStructure_Algorithms_PTIT/blob/main/NIG_sm_985.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

# %%
# !cp -r /content/drive/MyDrive/botnet_chord.tar.gz /content/data/botnet/raw

# %%
# !cd botnet_detection
# !python botnet_detection/setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating botdet.egg-info
# writing botdet.egg-info/PKG-INFO
# writing dependency_links to botdet.egg-info/dependency_links.txt
# writing requirements to botdet.egg-info/requires.txt
# writing top-level names to botdet.egg-info/top_level.txt
# writing manifest file 'botdet.egg-info/SOURCES.txt'
# reading manifest file 'botdet.egg-info/SOURCES.txt'
# writing manifest file 'botdet.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# warning: install_lib: 'build/lib' does not exist -- no Python modules to install
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying botdet.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying botdet.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying botdet.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying botdet.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying botdet.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/botdet-0.1.0-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing botdet-0.1.0-py3.7.egg
# Copying botdet-0.1.0-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding botdet 0.1.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/botdet-0.1.0-py3.7.egg
# Processing dependencies for botdet==0.1.0
# Searching for scikit-learn==1.0.2
# Best match: scikit-learn 1.0.2
# Adding scikit-learn 1.0.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for six==1.15.0
# Best match: six 1.15.0
# Adding six 1.15.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tqdm==4.64.1
# Best match: tqdm 4.64.1
# Adding tqdm 4.64.1 to easy-install.pth file
# Installing tqdm script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for deepdish==0.3.5
# Best match: deepdish 0.3.5
# Adding deepdish 0.3.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for h5py==3.1.0
# Best match: h5py 3.1.0
# Adding h5py 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numpy==1.21.6
# Best match: numpy 1.21.6
# Adding numpy 1.21.6 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.7 script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for torch==1.12.1+cu113
# Best match: torch 1.12.1+cu113
# Adding torch 1.12.1+cu113 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
# Installing torchrun script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for joblib==1.2.0
# Best match: joblib 1.2.0
# Adding joblib 1.2.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for threadpoolctl==3.1.0
# Best match: threadpoolctl 3.1.0
# Adding threadpoolctl 3.1.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for scipy==1.7.3
# Best match: scipy 1.7.3
# Adding scipy 1.7.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for tables==3.7.0
# Best match: tables 3.7.0
# Adding tables 3.7.0 to easy-install.pth file
# Installing pt2to3 script to /usr/local/bin
# Installing ptdump script to /usr/local/bin
# Installing ptrepack script to /usr/local/bin
# Installing pttree script to /usr/local/bin
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for cached-property==1.5.2
# Best match: cached-property 1.5.2
# Adding cached-property 1.5.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for typing-extensions==4.1.1
# Best match: typing-extensions 4.1.1
# Adding typing-extensions 4.1.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for numexpr==2.8.3
# Best match: numexpr 2.8.3
# Adding numexpr 2.8.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for packaging==21.3
# Best match: packaging 21.3
# Adding packaging 21.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Searching for pyparsing==3.0.9
# Best match: pyparsing 3.0.9
# Adding pyparsing 3.0.9 to easy-install.pth file
#
# Using /usr/local/lib/python3.7/dist-packages
# Finished processing dependencies for botdet==0.1.0

# %%
from botnet_detection.botdet.data.dataset_botnet import BotnetDataset
from botnet_detection.botdet.data.dataloader import GraphDataLoader

botnet_dataset_train = BotnetDataset(name='chord', split='train', in_memory = False, graph_format='pyg')
botnet_dataset_val = BotnetDataset(name='chord', split='val', in_memory = False, graph_format='pyg')
botnet_dataset_test = BotnetDataset(name='chord', split='test', in_memory = False, graph_format='pyg')
print(botnet_dataset_train)
# Out:
# Extracting data/botnet/raw/botnet_chord.tar.gz
# Processing...
# writing train set ----------
# 768it [02:09,  5.94it/s]
# train split --- number of graphs: 768, data saved at data/botnet/processed/chord_train.hdf5.
# writing val set ----------
# 96it [00:16,  5.71it/s]
# val split --- number of graphs: 96, data saved at data/botnet/processed/chord_val.hdf5.
# writing test set ----------
# 96it [00:16,  5.73it/s]
# test split --- number of graphs: 96, data saved at data/botnet/processed/chord_test.hdf5.
# Done!
# BotnetDataset(topology: chord | split: train | #graphs: 768 | graph format: pyg)

# %%
# !bash /content/botnet_detection/run_botnet.sh
# Out:
# All Logs will be saved to ./saved_models/chord_model_lay12_rh1_rw_ep50.log
# python /content/botnet_detection/train_botnet.py --devid 0 --data_dir ./data/botnet --data_name chord --batch_size 2 --enc_sizes 32 32 32 32 32 32 32 32 32 32 32 32 --act relu --residual_hop 1 --deg_norm sm --final proj --epochs 20 --lr 0.005 --early_stop 1 --save_dir ./saved_models --save_name chord_model_lay12_rh1_rw_ep50.pt
# ------------------------------
# Namespace(act='relu', aggr='add', batch_size=2, bias=True, data_dir='./data/botnet', data_name='chord', deg_norm='sm', devid=0, dropout=0.0, early_stop=1, enc_sizes=[32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32], epochs=20, final='proj', in_channels=1, in_memory=False, layer_act='none', log_interval=96, logmode='w', lr=0.005, n_classes=2, residual_hop=1, save_dir='./saved_models', save_name='chord_model_lay12_rh1_rw_ep50.pt', seed=0, shuffle=False, weight_decay=0.0005)
# ------------------------------
# Fri Oct 14 12:30:36 2022
# ------------------------------
# loading dataset...
# model ----------
# GCNModel(
#   (gcn_net): ModuleList(
#     (0): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 1, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 64)
#       (non_linear): Identity()
#     )
#     (1): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (2): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (3): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (4): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (5): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (6): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (7): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (8): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (9): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (10): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#     (11): GCNLayer(
#       (gcn): NodeModelMLP (in_channels: 32, out_channels: 32, in_edgedim: None, deg_norm: sm,aggr: add | number of parameters: 1056)
#       (non_linear): Identity()
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=False)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# epoch: 1, passed number of graphs: 96, train running loss: 1.75656 (passed time: 23s)
#           acc: 0.93040, fpr: 0.00043, fnr: 0.99980, rec: 0.00020, prc: 0.03306, f1: 0.00040, auroc: 0.60850
# epoch: 1, passed number of graphs: 192, train running loss: 0.94104 (passed time: 47s)
#           acc: 0.93160, fpr: 0.00003, fnr: 0.97960, rec: 0.02040, prc: 0.97842, f1: 0.03997, auroc: 0.71188
# epoch: 1, passed number of graphs: 288, train running loss: 0.66563 (passed time: 1m 11s)
